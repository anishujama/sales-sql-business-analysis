# %% [markdown]
# Import libararies

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv("final_cleaned_dataset.csv")

# %% [markdown]
# Dataset Overview

# %%
print(df.head())
# Out:
#   Transaction_ID Customer_ID      Customer_Name Product_ID    Product_Name  \
# 0         T00001       C6767        Bruce Lopez       P742           Table
# 1         T00002       C5256      unknown value       P336  unknown column
# 2         T00003       C8777  Jennifer Anderson       P647      Headphones
# 3         T00004       C3247    Catherine Silva       P930  unknown column
# 4         T00005       C2499      Amanda Macias       P537            Sofa
#
#       Category  Quantity  Unit_Price  Discount  Total_Amount    Profit  \
# 0         Home         8    25762.39    148.21     205950.91  10607.40
# 1  Electronics        10    28982.17   5909.23     283912.47  59714.77
# 2  Electronics         8    29890.16   8151.23     230970.05  44798.09
# 3  Electronics         1    43912.78  12778.16      31134.62   6876.39
# 4         Home         8     4665.62    382.79      36942.17   6988.91
#
#    Sales_Date  Order_Date Shipping_Date Payment_Method Sales_Channel  \
# 0  2025-08-19  2025-08-19    2025-08-23     Debit Card       Offline
# 1  2025-06-10  2025-06-10    2025-06-16     Debit Card        Online
# 2  2024-07-25  2024-07-25    2024-08-01     Debit Card       Offline
# 3  2024-10-30  2024-10-30    2024-11-03     Debit Card       Offline
# 4  2024-08-23  2024-08-23    2024-08-24            Upi       Offline
#
#                   City          State Region
# 0  New Christopherberg  West Virginia  North
# 1            Sheamouth       Oklahoma   West
# 2        Rodriguezberg       Missouri   East
# 3       Blanchardshire          Idaho   West
# 4         Lake Derrick  West Virginia   West

# %% [markdown]
# Shape Check

# %%
print(df.shape)
# Out:
# (9877, 19)

# %% [markdown]
# Statistical Summary

# %%
print(df.describe())
# Out:
#           Quantity    Unit_Price      Discount   Total_Amount         Profit
# count  9877.000000   9877.000000   9877.000000    9877.000000    9877.000000
# mean      5.461780  24778.366406   3703.454295  131238.631091   19606.224676
# std       2.864017  14199.396570   3280.460469  109378.997823   18871.051013
# min       1.000000    103.250000      0.230000      74.680000       6.290000
# 25%       3.000000  12319.960000    993.950000   39556.930000    5284.290000
# 50%       5.000000  24739.670000   2751.540000  100571.920000   13586.510000
# 75%       8.000000  36972.290000   5706.930000  195508.240000   27937.290000
# max      10.000000  49995.710000  14884.530000  445173.350000  110222.040000

# %% [markdown]
# Category Distribution

# %%
print(df["Category"].value_counts())
# Out:
# Category
# Books          2642
# Electronics    2510
# Clothing       2410
# Home           2315
# Name: count, dtype: int64

# %% [markdown]
# Payment method distribution

# %%
print(df["Payment_Method"].value_counts())
# Out:
# Payment_Method
# Debit Card     1947
# Cash           1941
# Upi            1925
# Net Banking    1899
# Credit Card    1867
# Unknown         298
# Name: count, dtype: int64

# %% [markdown]
# Histogram

# %%
plt.hist(df["Total_Amount"], bins=30)

plt.title("Total Amount Distribution")

plt.xlabel("Total Amount")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# BarCharts

# %%
category_sales = df.groupby("Category")["Total_Amount"].sum()

category_sales.plot(kind="bar")

plt.title("Sales by Category")

plt.ylabel("Total Sales")

plt.show()
